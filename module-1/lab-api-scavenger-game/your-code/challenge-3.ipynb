# %% [markdown]
# # Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in this repo whose filenames contain .scavengerhunt. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching on your computer.
#
# 1. Order them ascendingly based on the numeric value in the filenames.
#
# 2. Read the content of each secret files into an array of strings.
#
# 3. Concatenate the strings in the array separating each two with a whitespace.
#
# 4. Print out the joke.

# %% [markdown]
# ### Find Secret Files

# %%
import json
import requests
import pandas as pd

# %%
response = requests.get('https://api.github.com/search/code?q=filename:.scavengerhunt+repo:ironhack-datalabs/madrid-oct-2018')

# %%
results = response.json()
results
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0020.scavengerhunt',
#    'path': '.0020.scavengerhunt',
#    'sha': '41d25f51c301c5eee3737998b0d86573e4e91b90',
#    'url': 'https://api.github.com/repositories/153720804/contents/.0020.scavengerhunt?ref=48de91c634cdf5d535c274f98092adf2bb3fa347',
#    'git_url': 'https://api.github.com/repositories/153720804/git/blobs/41d25f51c301c5eee3737998b0d86573e4e91b90',
#    'html_url': 'https://github.com/ironhack-datalabs/madrid-oct-2018/blob/48de91c634cdf5d535c274f98092adf2bb3fa347/.0020.scavengerhunt',
#    'repository': {'id': 153720804,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=',
#     'name': 'madrid-oct-2018',
#     'full_name': 'ironhack-datalabs/madrid-oct-2018',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
# ...

# %%
data = pd.DataFrame(results)
print(type(data))
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    total_count  incomplete_results  \
# 0           24               False
# 1           24               False
# 2           24               False
# 3           24               False
# 4           24               False
#
#                                                items
# 0  {'name': '.0020.scavengerhunt', 'path': '.0020...
# 1  {'name': '.0007.scavengerhunt', 'path': 'final...
# 2  {'name': '.0015.scavengerhunt', 'path': 'modul...
# 3  {'name': '.0017.scavengerhunt', 'path': 'final...
# 4  {'name': '.0008.scavengerhunt', 'path': 'modul...

# %% [markdown]
# ### Order them ascendingly based on the numeric value in the filenames

# %%
from pandas.io.json import json_normalize

# %%
flattened_data = json_normalize(results['items']).sort_values('name')
print(type(flattened_data))
flattened_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                               git_url  \
# 7   https://api.github.com/repositories/153720804/...
# 23  https://api.github.com/repositories/153720804/...
# 16  https://api.github.com/repositories/153720804/...
# 19  https://api.github.com/repositories/153720804/...
# 6   https://api.github.com/repositories/153720804/...
# 21  https://api.github.com/repositories/153720804/...
# 1   https://api.github.com/repositories/153720804/...
# 4   https://api.github.com/repositories/153720804/...
# 9   https://api.github.com/repositories/153720804/...
# 20  https://api.github.com/repositories/153720804/...
# 13  https://api.github.com/repositories/153720804/...
# 17  https://api.github.com/repositories/153720804/...
# 5   https://api.github.com/repositories/153720804/...
# 22  https://api.github.com/repositories/153720804/...
# 2   https://api.github.com/repositories/153720804/...
# 10  https://api.github.com/repositories/153720804/...
# ...
