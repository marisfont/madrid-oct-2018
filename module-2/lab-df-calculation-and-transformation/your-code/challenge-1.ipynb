# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on pokemons... You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# ### Import all required libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
pokemon = pd.read_csv('Pokemon.csv')

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions as follows:
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | Sum of all stats that come after this, a general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# ### Print the distinct values in `Type 1` and `Type 2` combined

# %%
pd.concat([pokemon['Type 1'], pokemon['Type 2']]).unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %% [markdown]
# Check out the pokemon names in the first 10 rows. You find there are junk texts in the pokemon names which contain "Mega". For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".
#
# ### Cleanup `Name` that contain "Mega"

# %%
def clean(a):   
    if "Mega" in a: 
        return "Mega" + a.split("Mega")[-1]
    else:
        return a
    
pokemon['Name'] = pokemon['Name'].apply(clean)
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# pokemon['Name'] = pokemon['Name'].replace('.*Mega', 'Mega', regex=True)
# pokemon.head()

# %%
#pokemon.apply(lambda name: ("Mega" + name.split("Mega")[-1] if "Mega" in name else name))
# pokemon["Name"] = pokemon.apply(clean)
# pokemon.head()

# %%
# Solucion Marc
def press(x):
    newwords = []
    for word in x.split(' '):
        if word.endswith('Mega'):
            newwords.append('Mega')
            newwords.append(word.replace('Mega', ''))
        else: 
            if word not in newwords:
                newwords.append(word)
    return ' '.join(newwords)

pokemon['NameCleaned'] = pokemon['Name'].head(10).apply(press)
display(pokemon.head(3))
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary NameCleaned
# 0     45           1      False   Bulbasaur
# 1     60           1      False     Ivysaur
# 2     80           1      False    Venusaur

# %%
# top solucion - Constan
pokemon['Name'] = pokemon['Name'].replace('.*Mega','Mega', regex=True)
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary     NameCleaned
# 0       65     45           1      False       Bulbasaur
# 1       80     60           1      False         Ivysaur
# 2      100     80           1      False        Venusaur
# 3      120     80           1      False  Mega  Venusaur
# 4       50     65           1      False      Charmander

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, pokemon #1 has the Attack score 49 and Defense score 49. The corresponding `A/D Ratio` is 49/49=1.

# %%
pokemon['A/D Ratio'] = pokemon['Attack'] / pokemon['Defense']

pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary        NameCleaned  A/D Ratio
# 0       65     45           1      False          Bulbasaur   1.000000
# 1       80     60           1      False            Ivysaur   0.984127
# 2      100     80           1      False           Venusaur   0.987952
# 3      120     80           1      False     Mega  Venusaur   0.813008
# 4       50     65           1      False         Charmander   1.209302
# 5       65     80           1      False         Charmeleon   1.103448
# 6       85    100           1      False          Charizard   1.076923
# 7       85    100           1      False  Mega  Charizard X   1.171171
# 8      115    100           1      False  Mega  Charizard Y   1.333333
# 9       64     43           1      False           Squirtle   0.738462

# %% [markdown]
# ### Print the pokemon with the highest `A/D Ratio`

# %%
pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].max()]['Name']
# Out:
# 429    DeoxysAttack Forme
# Name: Name, dtype: object

# %% [markdown]
# ### Print the pokemon with the lowest A/D Ratio

# %%
pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].min()]['Name']
# Out:
# 230    Shuckle
# Name: Name, dtype: object

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Conditions:
#
# * If `Type 2` value is a valid string, the `Combo Type` value should be `<Type 1>-<Type 2>` (e.g. `Grass-Poison`).
#
# * If `Type 2` value is `NaN`, the `Combo Type` value should be the same as `Type 1` which always exists.
#
# *Hint: Consider using function and `apply`.*

# %%
def types(type1,type2):
    type3 = type1
    if type(type2) == str:
        type3 = type1 + '-' + type2 
    return type3

pokemon['Combo Type'] = pokemon.apply(lambda x: types(x['Type 1'], x['Type 2']), axis=1)
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary        NameCleaned  A/D Ratio  \
# 0       65     45           1      False          Bulbasaur   1.000000
# 1       80     60           1      False            Ivysaur   0.984127
# 2      100     80           1      False           Venusaur   0.987952
# 3      120     80           1      False     Mega  Venusaur   0.813008
# 4       50     65           1      False         Charmander   1.209302
# 5       65     80           1      False         Charmeleon   1.103448
# 6       85    100           1      False          Charizard   1.076923
# 7       85    100           1      False  Mega  Charizard X   1.171171
# 8      115    100           1      False  Mega  Charizard Y   1.333333
# 9       64     43           1      False           Squirtle   0.738462
#
#      Combo Type
# 0  Grass-Poison
# 1  Grass-Poison
# 2  Grass-Poison
# 3  Grass-Poison
# 4          Fire
# 5          Fire
# 6   Fire-Flying
# 7   Fire-Dragon
# 8   Fire-Flying
# 9         Water

# %% [markdown]
# ### Print `Combo Type` for pokemons whose `A/D Ratio` are among the top 5

# %%
top5 = pokemon.sort_values('A/D Ratio', ascending=False)['Combo Type'].head(5)
top5
# Out:
# 429       Psychic
# 347    Water-Dark
# 19     Bug-Poison
# 453          Rock
# 348    Water-Dark
# Name: Combo Type, dtype: object

# %% [markdown]
# ### For the 5 `Combo Type` values printed from the previous question, calculate the aggregated `Attack` scores for each `Combo Type`.

# %%
pokemon.groupby(['Combo Type'])['Attack'].sum().filter(top5)
# Out:
# Combo Type
# Psychic       2468
# Water-Dark     720
# Bug-Poison     820
# Rock           930
# Water-Dark     720
# Name: Attack, dtype: int64

# %% [markdown]
# ### `Total` formula hypothesis testing
#
# From the data descriptions you may have noticed there is a column called `Total` which indicates how strong the pokemon is. Make a hypothesis how `Total` is calculated and test your hypothesis.
#
# The general guideline is first examine the data carefully and make a guess how `Total` might have been calculated. You can write a math formula and convert it to a function. Then calculate the results based on your formula and store the results in a new column called `Guessed Total`. Next compare whether `Guessed Total` and `Total` contain the same values. If values match, congratuations you have verified your hypothesis! Otherwise, revise your formula, update the values in `Guessed Total`, and compare again.

# %%
pokemon['Guessed Total'] = pokemon['HP'] + pokemon['Attack'] + pokemon['Defense'] + pokemon['Sp. Atk'] + pokemon['Sp. Def'] + pokemon['Speed']
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary     NameCleaned  A/D Ratio  \
# 0       65     45           1      False       Bulbasaur   1.000000
# 1       80     60           1      False         Ivysaur   0.984127
# 2      100     80           1      False        Venusaur   0.987952
# 3      120     80           1      False  Mega  Venusaur   0.813008
# 4       50     65           1      False      Charmander   1.209302
#
#      Combo Type  Guessed Total
# 0  Grass-Poison            318
# 1  Grass-Poison            405
# 2  Grass-Poison            525
# 3  Grass-Poison            625
# 4          Fire            309

# %%
pokemon['Guessed Total1'] = pokemon[['HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed']].sum(axis=1)
pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary     NameCleaned  A/D Ratio  \
# 0       65     45           1      False       Bulbasaur   1.000000
# 1       80     60           1      False         Ivysaur   0.984127
# 2      100     80           1      False        Venusaur   0.987952
# 3      120     80           1      False  Mega  Venusaur   0.813008
# 4       50     65           1      False      Charmander   1.209302
#
#      Combo Type  Guessed Total  Guessed Total1
# 0  Grass-Poison            318             318
# 1  Grass-Poison            405             405
# 2  Grass-Poison            525             525
# 3  Grass-Poison            625             625
# 4          Fire            309             309
