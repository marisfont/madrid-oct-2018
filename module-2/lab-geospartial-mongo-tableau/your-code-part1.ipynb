# %% [markdown]
# # Lab Geospartial Mongo Tableau
# ## Part 1

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import pymongo as py
from pandas.io.json import json_normalize
import geojson
from geojson import Point, Feature, FeatureCollection, dump

# %% [markdown]
# ### Question 1
# Import the companies.json dataset into a mongodb collection
# - Step completed in MongoDB Compass and Kitematic

# %% [markdown]
# ### Question 2
# Using pymongo connect to the database and:
# 1. From all the companies get first office, number of people and company name

# %%
from pymongo import MongoClient 
client = MongoClient("mongodb://admin:admin@localhost:32770")
db = client.mybbdd

# %%
first_office = db.docs.find({"$and": [{"number_of_employees":{"$ne":None}}, {"offices.latitude":{"$ne":None}}, {"offices.longitude": {"$ne":None}}, {"offices": {"$ne":[]}}]}, projection={"name": 1 , "number_of_employees": 1, '_id':0, "offices.latitude": 1, "offices.longitude": 1})
first_office = list(first_office)

a = []
for item in first_office:
    a.append([item['offices'][0]['latitude'], item['offices'][0]['longitude'], item['number_of_employees'], item['name']])
print(type(a))
print(a[0])
# Out:
# <class 'list'>
# [37.692934, -121.904945, 600, 'AdventNet']

# %% [markdown]
# 2. Convert it to GeoJSON format
# 3. Insert it back to another mongodb collection
#     - Step completed in MongoDB Compass

# %%
list_points = []
for i in a:
    point = Point((i[1], i[0]))
    at = {"name": i[3], "number_of_employees": i[2], "geometry": {"type":point['type'], "coordinates":point['coordinates']}}
    list_points.append(at)
    points = pd.DataFrame(list_points)
points.head()
# Out:
#                                             geometry       name  \
# 0  {'type': 'Point', 'coordinates': [-121.904945,...  AdventNet
# 1  {'type': 'Point', 'coordinates': [-121.904945,...       Zoho
# 2  {'type': 'Point', 'coordinates': [-122.394523,...       Digg
# 3  {'type': 'Point', 'coordinates': [-122.333253,...   Wetpaint
# 4  {'type': 'Point', 'coordinates': [-118.393064,...       Geni
#
#    number_of_employees
# 0                  600
# 1                 1600
# 2                   60
# 3                   47
# 4                   18

# %%
with open("pointsfile.json", "w") as f:
    for i,e in points.iterrows():
        print(e.to_json())
        f.write(e.to_json()+"\n")
# Out:
# {"geometry":{"type":"Point","coordinates":[-121.904945,37.692934]},"name":"AdventNet","number_of_employees":600}
# {"geometry":{"type":"Point","coordinates":[-121.904945,37.692934]},"name":"Zoho","number_of_employees":1600}
# {"geometry":{"type":"Point","coordinates":[-122.394523,37.764726]},"name":"Digg","number_of_employees":60}
# {"geometry":{"type":"Point","coordinates":[-122.333253,47.603122]},"name":"Wetpaint","number_of_employees":47}
# {"geometry":{"type":"Point","coordinates":[-118.393064,34.090368]},"name":"Geni","number_of_employees":18}
# {"geometry":{"type":"Point","coordinates":[-118.39417,34.076179]},"name":"Fox Interactive Media","number_of_employees":0}
# {"geometry":{"type":"Point","coordinates":[-122.151801,37.41605]},"name":"Facebook","number_of_employees":5299}
# {"geometry":{"type":"Point","coordinates":[-122.4169244,37.7768052]},"name":"Twitter","number_of_employees":1300}
# ...
