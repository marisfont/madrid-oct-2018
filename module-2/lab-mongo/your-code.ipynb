# %% [markdown]
# # Lab Mongo

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import pymongo as py
from pandas.io.json import json_normalize

# %% [markdown]
# ### Set client and data base

# %%
from pymongo import MongoClient 
client = MongoClient("mongodb://admin:admin@localhost:32770")
db = client.mybbdd

# %% [markdown]
# ## Queries
# 1. All the companies that it's name match 'Babelgum'. Retrieve only their name field.

# %%
name_babelgum = db.docs.find({"name":{"$eq":"Babelgum"}})
name_babelgum[0]['name']
# Out:
# 'Babelgum'

# %% [markdown]
# 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by number of employees.

# %%
employees_5000 = db.docs.find({"number_of_employees":{"$gt":5000}}, projection={"_id": 0, "name": 1 , "number_of_employees": 1, "_id": 0}).sort("number_of_employees", py.DESCENDING).limit(20)
employees_5000 = pd.DataFrame(list(employees_5000))
employees_5000
# Out:
#                                           name  number_of_employees
# 0                                      Siemens               405000
# 1                                          IBM               388000
# 2                                       Toyota               320000
# 3                                       PayPal               300000
# 4   Nippon Telegraph and Telephone Corporation               227000
# 5                          Samsung Electronics               221726
# 6                                    Accenture               205000
# 7                    Tata Consultancy Services               200300
# 8                    Flextronics International               200000
# 9                                      Safeway               186000
# 10                                        Sony               180500
# 11                                          LG               177000
# 12                                        Ford               171000
# ...

# %% [markdown]
# 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the name and founded_yearfileds.

# %%
founded_2000_2005 = db.docs.find({"founded_year":{'$gte':2000,'$lte':2005}}, projection={"_id":0, "name": 1 , "founded_year": 1}).sort("founded_year", py.ASCENDING)
founded_2000_2005 = pd.DataFrame(list(founded_2000_2005))
founded_2000_2005
# Out:
#       founded_year                       name
# 0             2000                   AllofMP3
# 1             2000                     Steorn
# 2             2000                     MeeVee
# 3             2000                   PhotoBox
# 4             2000                     Boonex
# 5             2000                     Sulake
# 6             2000                SelectMinds
# 7             2000                 ContextWeb
# 8             2000                   ZoomInfo
# 9             2000                   eHarmony
# 10            2000                  Espotting
# 11            2000                       airG
# 12            2000                    Marchex
# 13            2000              ContactOffice
# 14            2000                      WooMe
# 15            2000                      Boomi
# 16            2000                     zSlide
# 17            2000                 Phrasebase
# 18            2000                    Ubertor
# ...

# %% [markdown]
# 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the name and ipo fields.

# %%
valuation_founded = db.docs.find({'$and' : [{"founded_year":{'$lt':2010}}, {"ipo.valuation_amount":{'$gt':100000000}}]},projection={"_id":0,"name": 1 , "founded_year": 1, "ipo.valuation_amount": 1})
valuation_founded = json_normalize(list(valuation_founded))
valuation_founded
# Out:
#     founded_year  ipo.valuation_amount                  name
# 0           2004          104000000000              Facebook
# 1           2006           18100000000               Twitter
# 2           2004            1300000000                  Yelp
# 3           2003            9310000000              LinkedIn
# 4           1994          100000000000                Amazon
# 5           2004             290000000            Brightcove
# 6           2008             235000000           KIT digital
# 7           1922            1600000000               Nielsen
# 8           1998            1050000000             OpenTable
# 9           2001             287000000        ChannelAdvisor
# 10          2001            1000000000         Jive Software
# 11          2005            2550000000                Zillow
# 12          2006             750000000                   Wix
# 13          1999             350000000            Shutterfly
# ...

# %% [markdown]
# 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
employees_founded = db.docs.find({'$and' : [{"founded_year":{'$lt':2005}}, {"number_of_employees":{"$lt":1000}}]}, projection={"name": 1 , "founded_year": 1, "number_of_employees": 1}).sort("number_of_employees", py.DESCENDING).limit(10)
employees_founded = pd.DataFrame(list(employees_founded))
employees_founded
# Out:
#                         _id  founded_year                             name  \
# 0  52cdef7d4bab8bd675298933          2000             Infinera Corporation
# 1  52cdef7e4bab8bd67529ac95          1997  NorthPoint Communications Group
# 2  52cdef7f4bab8bd67529be17          1997                     888 Holdings
# 3  52cdef7c4bab8bd6752986a2          1983               Forrester Research
# 4  52cdef7e4bab8bd67529af6d          1991                        SonicWALL
# 5  52cdef7e4bab8bd67529b21b          1999                       Webmetrics
# 6  52cdef7e4bab8bd67529b3bd          1999             Cornerstone OnDemand
# 7  52cdef7c4bab8bd675297de0          2004                             Yelp
# 8  52cdef7c4bab8bd675297ef5          2003                          MySpace
# 9  52cdef7c4bab8bd675297efd          2000                         ZoomInfo
#
#    number_of_employees
# 0                  974
# 1                  948
# 2                  931
# 3                  903
# ...

# %% [markdown]
# 6. All the companies that don't include the partners field.

# %%
no_partners = db.docs.find({"partners":{"$eq":[]}}, projection={"_id":0, "name": 1 , "partners": 1})
no_partners = pd.DataFrame(list(no_partners))
no_partners
# Out:
#                                  name partners
# 0                           AdventNet       []
# 1                                Zoho       []
# 2                                Digg       []
# 3                            Wetpaint       []
# 4                           Omnidrive       []
# 5                             Postini       []
# 6                                Geni       []
# 7                             Flektor       []
# 8               Fox Interactive Media       []
# 9                            Facebook       []
# 10                        StumbleUpon       []
# 11                             Gizmoz       []
# 12                            Twitter       []
# 13                            Slacker       []
# 14                               Lala       []
# 15                              Helio       []
# 16                             Scribd       []
# 17                            MeetMoi       []
# 18                               eBay       []
# ...

# %% [markdown]
# 7. All the companies that have a null type of value on the category_code field.
#     - There are no nulls, but there are none

# %%
null_category = db.docs.find({"category_code":{"$type":10}}, projection={"_id":0, "name": 1 , "category_code": 1})
null_category = pd.DataFrame(list(null_category))
null_category
# Out:
#      category_code                                      name
# 0             None                                Collective
# 1             None                                   Snimmer
# 2             None                                    KoolIM
# 3             None                                   VidKing
# 4             None                              Level9 Media
# 5             None                                     Drigg
# 6             None                                 SpaceTime
# 7             None                                    MMDAYS
# 8             None                              Inside Group
# 9             None                             Touch Clarity
# 10            None                            Repeater Store
# 11            None                                    Tapesh
# 12            None                                 iPersians
# 13            None                                 NewPersia
# ...

# %% [markdown]
# 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the name and number of employees fields.

# %%
employees_100_1000 = db.docs.find({"number_of_employees":{'$gte':100, "$lt":1000}}, projection={"_id": 0, "name": 1 , "number_of_employees": 1}).sort("number_of_employees", py.ASCENDING)
employees_100_1000 = pd.DataFrame(list(employees_100_1000))
employees_100_1000
# Out:
#                                 name  number_of_employees
# 0                             Redfin                  100
# 1                       Simply Hired                  100
# 2                                hi5                  100
# 3                    INgage Networks                  100
# 4                              mig33                  100
# 5                                Fon                  100
# 6                           EchoSign                  100
# 7                           TrialPay                  100
# 8                           Firetide                  100
# 9                         Verimatrix                  100
# 10                              Blyk                  100
# 11                  Survey Analytics                  100
# 12             Social Gaming Network                  100
# 13                           Covario                  100
# 14                         99designs                  100
# ...

# %% [markdown]
# 9. Order all the companies by their IPO price descendently.

# %%
valuation_sorted = db.docs.find({"ipo.valuation_amount":{'$type':'number'}}, projection={"_id": 0, "name": 1 ,"ipo.valuation_amount": 1}).sort("ipo.valuation_amount", py.DESCENDING)
valuation_sorted = json_normalize(list(valuation_sorted))
valuation_sorted
# Out:
#     ipo.valuation_amount                        name
# 0           108960000000                        GREE
# 1           104000000000                    Facebook
# 2           100000000000                      Amazon
# 3            18100000000                     Twitter
# 4            12800000000                     Groupon
# 5            11000000000                     Tencent
# 6             9430000000             Western Digital
# 7             9310000000                    LinkedIn
# 8             6000000000                BMC Software
# 9             5440000000                   Rackspace
# 10            4000000000                       Baidu
# 11            3273770000                 TripAdvisor
# 12            3000000000                    HomeAway
# 13            2550000000                      Zillow
# 14            1600000000                     Nielsen
# 15            1300000000                        Yelp
# 16            1100000000                       Chegg
# ...

# %% [markdown]
# 10. Retrieve the 10 companies with more employees, order by the number of employees

# %%
employees_top10 = db.docs.find(projection={"name": 1 , "number_of_employees": 1, '_id':0}).sort("number_of_employees", py.DESCENDING).limit(10)
employees_top10 = pd.DataFrame(list(employees_top10))
employees_top10
# Out:
#                                          name  number_of_employees
# 0                                     Siemens               405000
# 1                                         IBM               388000
# 2                                      Toyota               320000
# 3                                      PayPal               300000
# 4  Nippon Telegraph and Telephone Corporation               227000
# 5                         Samsung Electronics               221726
# 6                                   Accenture               205000
# 7                   Tata Consultancy Services               200300
# 8                   Flextronics International               200000
# 9                                     Safeway               186000

# %% [markdown]
# 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
founded_semester = db.docs.find({"founded_month":{'$gte':7, "$lte":12}}, projection={"_id": 0, "name": 1 ,"founded_month": 1}).limit(1000)
founded_semester = json_normalize(list(founded_semester))
founded_semester
# Out:
#      founded_month                         name
# 0                9                         Zoho
# 1               10                         Digg
# 2               10                     Wetpaint
# 3               11                    Omnidrive
# 4                9                         eBay
# 5               10                        Joost
# 6               11                        Plaxo
# 7               10                     Powerset
# 8               12                         Kyte
# 9                9              Jingle Networks
# 10              12                        Thoof
# 11              12                       Wesabe
# 12              11                      SmugMug
# 13               8                     LifeLock
# 14               8                        Skype
# 15               7               Pando Networks
# 16               9                       Google
# 17              12                         Ikan
# 18               9                    delicious
# ...

# %% [markdown]
# # Pending
# 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
founded_acquisition = db.docs.find({'$and' : [{"founded_year":{'$lt':2000}}, {"acquisition.price_amount":{'$gt':10000000}}]},projection={"_id":0,"name": 1 , "founded_year": 1, "acquisition.price_amount": 1})
founded_acquisition = json_normalize(list(founded_acquisition))
founded_acquisition
# Out:
#      acquisition.price_amount  founded_year                            name
# 0                   625000000          1999                         Postini
# 1                   180000000          1999                        SideStep
# 2                    25000000          1999                      Recipezaar
# 3                  1500000000          1998                          PayPal
# 4                   300000000          1999                        Snapfish
# 5                   160000000          1999                         Neopets
# 6                  7400000000          1982                Sun Microsystems
# 7                  1200000000          1999                          Zappos
# 8                  1000000000          1999                         Alibaba
# 9                  4300000000          1960                           Sabre
# 10                 1008000000          1998                      Lastminute
# ...

# %% [markdown]
# 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their nameand acquisiton field.
#     - Instruction is wrong, there are no values for 2015, therefore I changed it to acquired after 2005

# %%
founded_acquisition = db.docs.find({"acquisition.acquired_year":{'$gt':2005}}, projection={"_id":0,"name": 1 , "acquisition": 1}).sort("acquisition.price_amount", py.ASCENDING)
founded_acquisition = json_normalize(list(founded_acquisition))
founded_acquisition
# Out:
#       acquisition.acquired_day  acquisition.acquired_month  \
# 0                         28.0                        11.0
# 1                         15.0                        12.0
# 2                         24.0                        11.0
# 3                         31.0                         1.0
# 4                          7.0                         4.0
# 5                         31.0                        10.0
# 6                         13.0                         3.0
# 7                          1.0                         1.0
# 8                         27.0                         4.0
# 9                          1.0                        12.0
# 10                         5.0                         4.0
# 11                        30.0                         4.0
# 12                         7.0                         7.0
# 13                        16.0                        12.0
# 14                        14.0                        10.0
# ...

# %% [markdown]
# ## Optional
# 15. Order the companies by their founded year, retrieving only their name and founded year.
# 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their aquisition price descendently. Limit the search to 10 documents.
# 17. All the companies on the 'web' category that have more than 4000 employees. Sort them by the amount of employees in ascendant order.
# 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.
# 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their name and acquisition fields.
# 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.
