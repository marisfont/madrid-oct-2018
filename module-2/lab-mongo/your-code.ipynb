# %% [markdown]
# # Lab Mongo

# %% [markdown]
# - Import libraries

# %%
import pandas as pd
import pymongo as py

# %% [markdown]
# - set client and db

# %%
from pymongo import MongoClient 
client = MongoClient("mongodb://admin:admin@localhost:32770")
db = client.mybbdd

# %% [markdown]
# 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.
# 12. All the companies that have been 'deadpooled' after the third year.
# 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000
# 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their nameand acquisiton field.
# 15. Order the companies by their founded year, retrieving only their name and founded year.
# 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their aquisition price descendently. Limit the search to 10 documents.
# 17. All the companies on the 'web' category that have more than 4000 employees. Sort them by the amount of employees in ascendant order.
# 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.
# 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their name and acquisition fields.
# 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %% [markdown]
# 1. All the companies that it's name match 'Babelgum'. Retrieve only their name field.

# %%
name_babelgum = db.docs.find({"name":{"$eq":"Babelgum"}})
name_babelgum[0]['name']
# Out:
# 'Babelgum'

# %% [markdown]
# 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by number of employees.

# %%
employees_5000 = db.docs.find({"number_of_employees":{"$gt":5000}}, projection={"name": 1 , "number_of_employees": 1, "_id": 0}).sort("number_of_employees", py.DESCENDING).limit(20)
employees_5000 = pd.DataFrame(list(employees_5000))
employees_5000
# Out:
#                                           name  number_of_employees
# 0                                      Siemens               405000
# 1                                          IBM               388000
# 2                                       Toyota               320000
# 3                                       PayPal               300000
# 4   Nippon Telegraph and Telephone Corporation               227000
# 5                          Samsung Electronics               221726
# 6                                    Accenture               205000
# 7                    Tata Consultancy Services               200300
# 8                    Flextronics International               200000
# 9                                      Safeway               186000
# 10                                        Sony               180500
# 11                                          LG               177000
# 12                                        Ford               171000
# ...

# %% [markdown]
# 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the name and founded_yearfileds.

# %%
founded_2000_2005 = db.docs.find({"founded_year":{'$gte':2000,'$lte':2005}}, projection={"name": 1 , "founded_year": 1}).sort("founded_year", py.ASCENDING)
founded_2000_2005 = pd.DataFrame(list(founded_2000_2005))
founded_2000_2005
# Out:
#                            _id  founded_year                       name
# 0     52cdef7c4bab8bd675297dd5          2000                   AllofMP3
# 1     52cdef7c4bab8bd675297dd9          2000                     Steorn
# 2     52cdef7c4bab8bd675297ddb          2000                     MeeVee
# 3     52cdef7c4bab8bd675297e38          2000                   PhotoBox
# 4     52cdef7c4bab8bd675297e73          2000                     Boonex
# 5     52cdef7c4bab8bd675297ea9          2000                     Sulake
# 6     52cdef7c4bab8bd675297eb6          2000                SelectMinds
# 7     52cdef7c4bab8bd675297ef2          2000                 ContextWeb
# 8     52cdef7c4bab8bd675297efd          2000                   ZoomInfo
# 9     52cdef7c4bab8bd675297f12          2000                   eHarmony
# 10    52cdef7c4bab8bd675297f39          2000                  Espotting
# 11    52cdef7c4bab8bd675297f3e          2000                       airG
# ...

# %% [markdown]
# 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the name and ipo fields.

# %%
valuation_founded = db.docs.find({'$and' : [{"founded_year":{'$lt':2010}}, {"ipo.valuation_amount":{'$gt':100000000}}]},projection={"name": 1 , "founded_year": 1, "ipo.valuation_amount": 1})
valuation_founded = pd.DataFrame(list(valuation_founded))
valuation_founded
# Out:
#                          _id  founded_year  \
# 0   52cdef7c4bab8bd675297d8e          2004
# 1   52cdef7c4bab8bd675297d94          2006
# 2   52cdef7c4bab8bd675297de0          2004
# 3   52cdef7c4bab8bd675297e0c          2003
# 4   52cdef7c4bab8bd675297e7a          1994
# 5   52cdef7c4bab8bd675297e81          2004
# 6   52cdef7c4bab8bd675297ee5          2008
# 7   52cdef7c4bab8bd675297f15          1922
# 8   52cdef7c4bab8bd675297f36          1998
# 9   52cdef7c4bab8bd675297f42          2001
# 10  52cdef7c4bab8bd675297f95          2001
# 11  52cdef7c4bab8bd67529800c          2005
# 12  52cdef7c4bab8bd67529805d          2006
# 13  52cdef7c4bab8bd675298112          1999
# 14  52cdef7c4bab8bd6752981a7          2000
# 15  52cdef7c4bab8bd67529823b          1999
# 16  52cdef7c4bab8bd6752982f6          2005
# 17  52cdef7c4bab8bd6752984e3          1999
# 18  52cdef7c4bab8bd675298527          1998
# 19  52cdef7c4bab8bd67529859a          1980
# 20  52cdef7c4bab8bd675298649          2000
# ...

# %% [markdown]
# 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
employees_founded = db.docs.find({'$and' : [{"founded_year":{'$lt':2005}}, {"number_of_employees":{"$lt":1000}}]}, projection={"name": 1 , "founded_year": 1, "number_of_employees": 1})
employees_founded = pd.DataFrame(list(employees_founded))
employees_founded
# Out:
#                            _id  founded_year  \
# 0     52cdef7c4bab8bd675297d8b          1996
# 1     52cdef7c4bab8bd675297d8d          2004
# 2     52cdef7c4bab8bd675297d93          1979
# 3     52cdef7c4bab8bd675297da1          2002
# 4     52cdef7c4bab8bd675297da5          2002
# 5     52cdef7c4bab8bd675297da7          2004
# 6     52cdef7c4bab8bd675297db2          2002
# 7     52cdef7c4bab8bd675297db8          2002
# 8     52cdef7c4bab8bd675297dbc          2003
# 9     52cdef7c4bab8bd675297dc3          2004
# 10    52cdef7c4bab8bd675297dc6          2003
# 11    52cdef7c4bab8bd675297dda          2003
# 12    52cdef7c4bab8bd675297de0          2004
# 13    52cdef7c4bab8bd675297de8          2003
# 14    52cdef7c4bab8bd675297deb          1999
# 15    52cdef7c4bab8bd675297ded          2003
# 16    52cdef7c4bab8bd675297def          2004
# 17    52cdef7c4bab8bd675297df8          2004
# 18    52cdef7c4bab8bd675297e06          2003
# 19    52cdef7c4bab8bd675297e11          2002
# ...

# %% [markdown]
# 6. All the companies that don't include the partners field.

# %%
no_partners = db.docs.find({"partners":{"$eq":[]}}, projection={"name": 1 , "partners": 1})
no_partners = pd.DataFrame(list(no_partners))
no_partners
# Out:
#                             _id                            name partners
# 0      52cdef7c4bab8bd675297d8b                       AdventNet       []
# 1      52cdef7c4bab8bd675297d8c                            Zoho       []
# 2      52cdef7c4bab8bd675297d8d                            Digg       []
# 3      52cdef7c4bab8bd675297d8a                        Wetpaint       []
# 4      52cdef7c4bab8bd675297d8f                       Omnidrive       []
# 5      52cdef7c4bab8bd675297d90                         Postini       []
# 6      52cdef7c4bab8bd675297d91                            Geni       []
# 7      52cdef7c4bab8bd675297d92                         Flektor       []
# 8      52cdef7c4bab8bd675297d93           Fox Interactive Media       []
# 9      52cdef7c4bab8bd675297d8e                        Facebook       []
# 10     52cdef7c4bab8bd675297d95                     StumbleUpon       []
# 11     52cdef7c4bab8bd675297d96                          Gizmoz       []
# ...

# %% [markdown]
# 7. All the companies that have a null type of value on the category_code field.
#     - There are no nulls, but there are none

# %%
null_category = db.docs.find({"category_code":{"$type":10}}, projection={"name": 1 , "category_code": 1})
null_category = pd.DataFrame(list(null_category))
null_category
# Out:
#                            _id category_code  \
# 0     52cdef7c4bab8bd6752980f6          None
# 1     52cdef7c4bab8bd675298225          None
# 2     52cdef7c4bab8bd675298226          None
# 3     52cdef7c4bab8bd675298262          None
# 4     52cdef7c4bab8bd675298261          None
# 5     52cdef7c4bab8bd67529826e          None
# 6     52cdef7c4bab8bd675298276          None
# 7     52cdef7c4bab8bd67529827a          None
# 8     52cdef7c4bab8bd67529827b          None
# 9     52cdef7c4bab8bd675298279          None
# 10    52cdef7c4bab8bd67529827e          None
# 11    52cdef7c4bab8bd675298288          None
# 12    52cdef7c4bab8bd675298289          None
# 13    52cdef7c4bab8bd67529828a          None
# 14    52cdef7c4bab8bd6752982ab          None
# 15    52cdef7c4bab8bd6752982b3          None
# 16    52cdef7c4bab8bd6752982e0          None
# 17    52cdef7c4bab8bd6752982e4          None
# 18    52cdef7c4bab8bd6752982ef          None
# 19    52cdef7c4bab8bd6752982f2          None
# ...

# %% [markdown]
# 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the name and number of employees fields.

# %%
employees_100_1000 = db.docs.find({"number_of_employees":{'$gte':100, "$lt":1000}}, projection={"name": 1 , "number_of_employees": 1}).sort("number_of_employees", py.ASCENDING)
employees_100_1000 = pd.DataFrame(list(employees_100_1000))
employees_100_1000
# Out:
#                           _id                             name  \
# 0    52cdef7c4bab8bd675297e19                           Redfin
# 1    52cdef7c4bab8bd675297e27                     Simply Hired
# 2    52cdef7c4bab8bd675297e44                              hi5
# 3    52cdef7c4bab8bd675297eb2                  INgage Networks
# 4    52cdef7c4bab8bd675297fda                            mig33
# 5    52cdef7c4bab8bd67529802b                              Fon
# 6    52cdef7c4bab8bd67529805f                         EchoSign
# 7    52cdef7c4bab8bd67529806d                         TrialPay
# 8    52cdef7c4bab8bd675298073                         Firetide
# 9    52cdef7c4bab8bd6752980d9                       Verimatrix
# 10   52cdef7c4bab8bd6752980f1                             Blyk
# 11   52cdef7c4bab8bd675298258                 Survey Analytics
# 12   52cdef7c4bab8bd67529831a            Social Gaming Network
# 13   52cdef7c4bab8bd67529839d                          Covario
# ...

# %% [markdown]
# 9. Order all the companies by their IPO price descendently.

# %%
valuation_sorted = db.docs.find({"ipo.valuation_amount":{'$type':'number'}},projection={"name": 1 ,"ipo.valuation_amount": 1}).sort("ipo.valuation_amount", py.DESCENDING)
valuation_sorted = pd.DataFrame(list(valuation_sorted))
valuation_sorted
# Out:
#                          _id                                 ipo  \
# 0   52cdef7e4bab8bd67529a8b4  {'valuation_amount': 108960000000}
# 1   52cdef7c4bab8bd675297d8e  {'valuation_amount': 104000000000}
# 2   52cdef7c4bab8bd675297e7a  {'valuation_amount': 100000000000}
# 3   52cdef7c4bab8bd675297d94   {'valuation_amount': 18100000000}
# 4   52cdef7d4bab8bd675299d5d   {'valuation_amount': 12800000000}
# 5   52cdef7c4bab8bd675298674   {'valuation_amount': 11000000000}
# 6   52cdef7e4bab8bd67529b996    {'valuation_amount': 9430000000}
# 7   52cdef7c4bab8bd675297e0c    {'valuation_amount': 9310000000}
# 8   52cdef7c4bab8bd67529859a    {'valuation_amount': 6000000000}
# 9   52cdef7c4bab8bd675298527    {'valuation_amount': 5440000000}
# 10  52cdef7c4bab8bd675298760    {'valuation_amount': 4000000000}
# 11  52cdef7c4bab8bd6752981a7    {'valuation_amount': 3273770000}
# 12  52cdef7c4bab8bd6752982f6    {'valuation_amount': 3000000000}
# ...

# %% [markdown]
# 10. Retrieve the 10 companies with more employees, order by the number of employees
